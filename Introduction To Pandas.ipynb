# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/TopSellingAlbums.csv")

# %%
df
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
df = pd.read_excel("/content/drive/MyDrive/TopSellingAlbums.xlsx")

# %%
df
# Out:
#             Artist                            Album  Released    Length  \
# 0  Michael Jackson                         Thriller      1982  00:42:19
# 1            AC/DC                    Back in Black      1980  00:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston                    The Bodyguard      1992  00:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  00:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6         Bee Gees             Saturday Night Fever      1977  01:15:54
# 7    Fleetwood Mac                          Rumours      1977  00:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# ...

# %%
# Access to the column Length

x = df[['Length']]
x
# Out:
#      Length
# 0  00:42:19
# 1  00:42:11
# 2  00:42:49
# 3  00:57:44
# 4  00:46:33
# 5  00:43:08
# 6  01:15:54
# 7  00:40:01

# %%
x = df['Length']
x
# Out:
# 0    00:42:19
# 1    00:42:11
# 2    00:42:49
# 3    00:57:44
# 4    00:46:33
# 5    00:43:08
# 6    01:15:54
# 7    00:40:01
# Name: Length, dtype: object

# %%
# Get the column as a dataframe

x = df[['Artist']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
# Access to multiple columns

y = df[['Artist', 'Length', 'Genre']]
y
# Out:
#             Artist    Length                        Genre
# 0  Michael Jackson  00:42:19               pop, rock, R&B
# 1            AC/DC  00:42:11                    hard rock
# 2       Pink Floyd  00:42:49             progressive rock
# 3  Whitney Houston  00:57:44               R&B, soul, pop
# 4        Meat Loaf  00:46:33  hard rock, progressive rock
# 5           Eagles  00:43:08   rock, soft rock, folk rock
# 6         Bee Gees  01:15:54                        disco
# 7    Fleetwood Mac  00:40:01                    soft rock

# %%
# Access the value on the first row and the first column

df.iloc[0, 0]
# Out:
# 'Michael Jackson'

# %%
# Access the value on the second row and the first column

df.iloc[1, 0]
# Out:
# 'AC/DC'

# %%
# Access the value on the first row and the third column

df.iloc[0, 2]
# Out:
# 1982

# %%
# Access the value on the second row and the third column
df.iloc[1, 2]
# Out:
# 1980

# %%
# Access the column using the name

df.loc[1, 'Artist']
# Out:
# 'AC/DC'

# %%
# Access the column using the name

df.loc[1, 'Artist']
# Out:
# 'AC/DC'

# %%
# Access the column using the name

df.loc[0, 'Released']
# Out:
# 1982

# %%
# Access the column using the name

df.loc[1, 'Released']
# Out:
# 1980

# %%
# Slicing the dataframe

df.iloc[0: 2, 0: 3]
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
# Slicing the dataframe using name

df.loc[0: 2, 'Artist': 'Released']
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
q = df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
print('Because You all puppies are wives')
print("And politicians")
# Out:
# Because You all puppies are wives
# And politicians

# %%
# Write your code below and press Shift+Enter to execute

q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
# Write your code below and press Shift+Enter to execute

df.iloc[1, 2]
# Out:
# 1980

# %%
new_index=['a','b','c','d','e','f','g','h']

df_new = df
df_new.index = new_index
df_new.loc['a', 'Artist']
df_new.loc['a':'d', 'Artist']
# Out:
# a    Michael Jackson
# b              AC/DC
# c         Pink Floyd
# d    Whitney Houston
# Name: Artist, dtype: object

# %%
import pandas as pd

# %%
# Create a Series from a list
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s[2]) # Access the element with label 2 (value 30)
# Out:
# 30

# %%
print(s.iloc[3]) # Access the element at position 3 (value 40)
# Out:
# 40

# %%
print(s[1: 4])  # Access a range of elements by label
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd

# %%
# Creating a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 28],
    'City': ['New york', 'San Francisco', 'Los Angles', 'Chicago']
        }
df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New york
# 1      Bob   30  San Francisco
# 2  Charlie   35     Los Angles
# 3    David   28        Chicago

# %%
df
# Out:
#       Name  Age           City
# 0    Alice   25       New york
# 1      Bob   30  San Francisco
# 2  Charlie   35     Los Angles
# 3    David   28        Chicago

# %%
print(df['Name']) # Access the 'Name' column
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
print(df.iloc[2]) # Access the third row by position
print(df.loc[1]) # Access the second row by label
# Out:
# Name       Charlie
# Age             35
# City    Los Angles
# Name: 2, dtype: object
# Name              Bob
# Age                30
# City    San Francisco
# Name: 1, dtype: object

# %%
print(df[['Name', 'Age']]) # Select specific columns
print(df[1: 3]) # Select specific rows
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   28
#       Name  Age           City
# 1      Bob   30  San Francisco
# 2  Charlie   35     Los Angles

# %%
unique_dates = df['Age'].unique()

# %%
unique_dates
# Out:
# array([25, 30, 35, 28])

# %%
high_above_102 = df[df['Age'] > 25]

# %%
high_above_102
# Out:
#       Name  Age           City
# 1      Bob   30  San Francisco
# 2  Charlie   35     Los Angles
# 3    David   28        Chicago
